# %% [markdown]
# <a href="https://colab.research.google.com/github/jawwad-ali/python-course/blob/main/fifth_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
social_media_posts_title = ["post1", "post2", "post3"]

# Append Items to the Lists

social_media_posts_title.append("post4")

print(social_media_posts_title)

social_media_posts_title.append('post5')
print(social_media_posts_title)
# Out:
# ['post1', 'post2', 'post3', 'post4']
# ['post1', 'post2', 'post3', 'post4', 'post5']

# %%
# Remove items from the lists


social_media_posts_title.remove("post4")
print(social_media_posts_title)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4167/867128766.py in <cell line: 0>()
#       2
#       3
# ----> 4 social_media_posts_title.remove("post4")
#       5 print(social_media_posts_title)
#       6
#
# ValueError: list.remove(x): x not in list

# %%
social_media_posts_title.remove("post1")
print(social_media_posts_title)
# Out:
# ['post2', 'post3', 'post5']

# %%
social_media_posts_title.clear()
print(social_media_posts_title)
# Out:
# []

# %%
# Dictionary In Python - collection of Key/value pair

cart = {}
print(type(cart))



cart = {
    "item_1": "Beef",
    "item_2": "Fish"
}
print(cart)
# Out:
# <class 'dict'>
# {'item_1': 'Beef', 'item_2': 'Fish'}

# %%
print(cart["item_1"])
print(cart["item_2"])
# Out:
# Beef
# Fish

# %%
fruits = {
    "name": "Mango",
    "price": "Rs 200",
    "unit": "KG"
}
print(fruits)
# Out:
# {'name': 'Mango', 'price': 'Rs 200', 'unit': 'KG'}

# %%
fruits = [ "Mango" , 123 , True, 78.11, [] , {} ]

# %%
vegetables_stall = [
    {
       "name": "Potato",
       "price": "200",
        "unit": "KG",
    },
    {
        "name": "Tomato",
        "price": "180",
        "unit": "KG"
    }
]

print(vegetables_stall[0]["name"])
print(vegetables_stall[0])
# Out:
# Potato
# {'name': 'Potato', 'price': '200', 'unit': 'KG'}

# %%
# Create a receipt using appropriate python data types

# 3 tshirts price 2500, 4 jeans 6500 , 2 pairs shoes 4000

shopping_list = [
    {
        "product_name" : "Tshirts",
        "price": 2500,
        "quantity": 3
    },
    {
        "product_name": "Jeans",
        "price":6500,
        "quantity": 4
    }

]
print(shopping_list[0]["price"] + shopping_list[1]["price"])
# Out:
# 9000
