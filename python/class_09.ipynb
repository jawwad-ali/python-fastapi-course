# %% [markdown]
# <a href="https://colab.research.google.com/github/jawwad-ali/python-course/blob/main/class_nine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# API (Application programming Interface)

# Modules
import requests


url = requests.get("https://simple-books-api.click")
result = url.json()
print(result)
# Out:
# {'message': 'Welcome to the Simple Books API.'}

# %%
endpoint = requests.get("https://simple-books-api.click/books")
result = url.json()
print(result)
# Out:
# [{'id': 1, 'name': 'The Russian', 'type': 'fiction', 'available': True}, {'id': 3, 'name': 'The Vanishing Half', 'type': 'fiction', 'available': True}, {'id': 4, 'name': 'The Midnight Library', 'type': 'fiction', 'available': True}, {'id': 6, 'name': 'Viscount Who Loved Me', 'type': 'fiction', 'available': True}, {'id': 2, 'name': 'Just as I Am', 'type': 'non-fiction', 'available': False}, {'id': 5, 'name': 'Untamed', 'type': 'non-fiction', 'available': True}]

# %%
# JSON placeholder API
